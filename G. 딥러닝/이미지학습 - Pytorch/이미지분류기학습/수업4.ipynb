# %% [markdown]
# ### Stochastic Gradient Descent
#
#   ? Autograd
#
# - Backpropagation & Chain Rule
#   - 뒤부터 서서히 역전파 (미분값을 순차적으로 구한다.)
#     ![image.png](attachment:image.png)
#
#     - optim.step() -> 위에서 지정한 방법대로 파라미터 변화시키는 단계
# - Deep Learning Algotithm Basics
#
#     - 딥러닝 코드 기본 구성
#       - 모델? (layer정의 부분, 네트워크 forward 부분)
#
# - Convolutional Neural Network (CNN)
#     - input 이미지를 filter를 통과 시켜 (합성곱) output 도출
#     - 여기서 그 filter가 parameter가  되는 것. (최적의 파라미터를 구하는 것이다.)
#     - padding을 써서 가로*세로의 크기를 그대로 유지하도록 하는 경우가 많다.
#   - pooling layer (CNN)
#     - 크기를 줄이고 싶을 때.
#     - 종류
#       - max pooling
#       - average pooling
#   - Fully Connected Layer (layer)
#     - matrix 곱과 같다.
#     - input 채널 수* output 채널 수 만큼의 연산을 하는 것.
#     - pytorch에 내장된 형태:
#   - Activation Layer
#     - 비선형성 추가. (표현할 수 있는 것의 범위가 넓어짐)
#     - 내부 학습 파라미터가 없다.
#     - 많이 써보니.. ReLU, Softmax가 유용하더라.
# - LeNet
#
# - VGG
#   - ImageNet (이미지classification대회)에서 준우승.
#   - "layer가 깊어질수록 성능이 좋아질 것"
# - Resnet
#   - ImageNet 준우승
#   - "layer가 너무 깊어져도 성능이 떨어짐."
#     - 미분값이 작아져 weight의 영향이 작아지는 gradient vanishing 발생
#     - skip connection을 이용해 해결
# - U-net
#   - Biomedical 분야에서 Image Segmentation을 목적으로 제안된 End-to-End 방식의 fully-convolutional Network
#     - (Fully connected layer 를 마지막에 쓰는 대신.)
#     - up-convolution이라는 형태로 feature값을 크게 해줌
#
# -> VGG, Resnet, U-net 은 최근에도 많이 쓰임.
# -> pytorch에 모델이 저장되어 있어 버전에 맞게 load해 쓸 수 있음. (pretrained =True: 학습된 모델이 나옴.)

# %% [markdown]
# Data & Dataloader
#
# > 파이토치에서 정의하는 대로 데이터를 정의해주면 Dataloader를 쓸 수 있다.

# %% [markdown]
# ### Cross Entropy Loss
# - Cross Entropy Loss 란?
#     ![image.png](attachment:image.png)
#
# - Pytorch CEL 코드
#      ![image-2.png](attachment:image-2.png)

# %% [markdown]
# https://tutorials.pytorch.kr/beginner/blitz/cifar10_tutorial.html

# %%
import torch.nn
import torch

loss = torch.mm.CrossEntropyLoss()
input = torch.radn(3, 5, requires_grad=True)
target = torch.empty(3, )

# %%
transpose -> [[3],[32],[32]] 를 [[32],[32],[3]]으로 바꿔줘야 이미지가 뜬다.

# %%
transform = transforms.Compose(
    [transforms.To.Tensor(),
     transforms.Normalize()]
)
https://pytorch.org/vision/main/generated/torchvision.transforms.ToTensor.html
