# %% [markdown]
# # 다중선형회귀 + 학습성능 개선
#
# > 농어의 무게 예측 데이터 셋
#
# 텐서플로우의 학습성능을 개선하기 위해 아래의 기능을 사용할 수 있음
#
# - 데이터 표준화: 학습률 향상에 도움을 줌
# - 콜백함수: 모델의 학습 방향, 저장 시점, 학습 정지 시점 등에 관한 상황을 설정 하기 위한 도구
#
# ## #01. 준비작업
#
# ### [1] 패키지 가져오기

# %%
# 연결된 모듈이 업데이트 되면 즉시 자동 로드함
# %load_ext autoreload
# %autoreload 2

from hossam.util import *
from hossam.plot import *

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# 학습에 대한 콜백함수 참조
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

# %% [markdown]
# ### [2] 데이터셋 준비하기

# %%
origin = my_read_excel(path='https://data.hossam.kr/mldata/fish.xlsx', info=False)
# Out:
# 상위 5개 행
# +----+--------+--------+--------+--------+
# |    |   길이 |   높이 |   두께 |   무게 |
# |----+--------+--------+--------+--------|
# |  0 |    8.4 |   2.11 |   1.41 |    5.9 |
# |  1 |   13.7 |   3.53 |      2 |     32 |
# |  2 |     15 |   3.82 |   2.43 |     40 |
# |  3 |   16.2 |   4.59 |   2.63 |   51.5 |
# |  4 |   17.4 |   4.59 |   2.94 |     70 |
# +----+--------+--------+--------+--------+

# %% [markdown]
# ## #02. 데이터 전처리
#
# ### [1] 훈련/검증 데이터 분리
#
# **데이터 정규화(스케일링)** 을 수행함
#
# 데이터에 정규화 처리를 적용하면 쉽게 최적값에 도달할 수 있으며 학습률을 상대적으로 높여서 사용할 수 있기 때문에 빠르게 훈련시킬 수 있다.

# %%
x_train, x_test, y_train, y_test = my_train_test_split(origin, yname='무게', scalling=True)
rows, cols = x_train.shape
rows, cols
# Out:
# (44, 3)

# %% [markdown]
# ## #03. 훈련 모델 적합
#
# ### [1] 신경망 정의
#
# | 구분 | 모델 | 활성화 함수 | 옵티마이저 | 손실함수 | 평가지표 | 대표예제 |
# |--|--|--|--|--|--|--|
# | 회귀 | 단순선형회귀 | relu, relu, linear | adam | mse | mae | 보스턴 집값 예측 |

# %%
model = Sequential()
# 최종 검증 손실률: 169142.234375, 최종 검증 절대오차: 315.249176
# model.add(Dense(4, activation = 'relu', input_shape = (cols, )))
# model.add(Dense(2, activation = 'relu'))

# 최종 검증 손실률: 193492.796875, 최종 검증 절대오차: 347.600739
model.add(Dense(8, activation = 'relu', input_shape = (cols, )))
model.add(Dense(4, activation = 'relu'))

# ... (16, 8), (32, 16) 에 대한 테스트 결과는 생략함

# 최종 검증 손실률: 2974.242920, 최종 검증 절대오차: 36.543842
model.add(Dense(64, activation = 'relu', input_shape = (cols, )))
model.add(Dense(32, activation = 'relu'))

# 최종 검증 손실률: 4515.570801, 최종 검증 절대오차: 40.064499
# model.add(Dense(128, activation = 'relu', input_shape = (cols, )))
# model.add(Dense(64, activation = 'relu'))

model.add(Dense(1, activation='linear'))
model.compile(optimizer = 'adam', loss = 'mse', metrics = ['mae'])
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 8)              │            32 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 4)              │            36 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 64)             │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,501 (9.77 KB)
#  Trainable params: 2,501 (9.77 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# #### 8, 4
#
# 최종 검증 손실률: 193492.796875, 최종 검증 절대오차: 347.600739
#
# ![image.png](attachment:image.png)
#
# #### 64, 32
#
# 최종 검증 손실률: 2974.242920, 최종 검증 절대오차: 36.543842
#
# ![image-2.png](attachment:image-2.png)
#
# #### 128, 64
#
# 최종 검증 손실률: 4515.570801, 최종 검증 절대오차: 40.064499
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ### [2] 콜백함수를 적용하여 학습하기
#
# 모델의 학습 방향, 저장 시점, 학습 정지 시점 등에 관한 상황을 설정하기 위한 도구
#
# #### 콜백함수 사용 방법
#
# ```python
# # 콜백 정의
# callbacks = [  콜백1, 콜백2, ... 콜백n  ]
#
# # 학습을 위한 fit() 함수에서 callbacks 파라미터에 미리 정의한 리스트를 지정
# callbacks = [콜백1, 콜백2, ... , 콜백n]
# model.fit(x_train, y_train, validation_data = (x_val, y_val), epochs = 500,
#         callbacks = callbacks)
# ```
#
# 혹은
#
# ```python
# model.fit(x_train, y_train, validation_data = (x_val, y_val), epochs = 500,
#     callbacks = [
#         콜백1, 콜백2, ... , 콜백n
# ])
# ```
#
# #### 콜백함수 종류
#
# ##### 1) EarlyStopping()
#
# 모델 학습 시에 지정된 기간 동안 모니터링하는 평가지표에서 더 이상 성능 향상이 일어나지 않은 경우 학습을 스스로 중단
#
# ```python
# EarlyStopping(monitor='평가지표', patience=10, verbose=1)
# ```
#
# - patience: 지정한 수만큼의 기간에서 평가지표의 향상이 일어나지 않을 경우 학습을 중단 (기간이라 함은 에폭을 의미) 예를 들어 patience=10일 때, 10에폭 동안 성능 향상이 일어나지 않으면 학습을 중단. 즉, 10회 이상 성능향상이 발견되지 않으면 중단함
# - verbose: 콜백의 수행 과정 노출 여부를 지정.
#     - 0: 아무런 표시 하지 않음(기본값)
#     - 1: 프로그래스바로 표시
#     - 2: 매 에폭마다 수행과정을 자세하게 출력함.
#
#
# ##### 2) ReduceLROnPlateau()
#
# EarlyStopping 콜백과 같이 patience 인자를 지정하여, 지정된 기간 동안 평가지표에서 성능 향상이 일어나지 않으면 학습률을 조정하는 콜백
#
# ```python
# ReduceLROnPlateau(monitor='평가지표', factor=0.1, patience=10, min_lr=0, verbose=1)
# ```
#
# - factor: 학습률 조정에 사용되는 값 (새로운 학습률 = factor * 기존 학습률)
# - patience: 지정한 수만큼의 기간에서 성능 향상이 일어나지 않을 경우, 학습률을 조정
# - min_lr: 학습률의 하한을 지정
# - verbose: 콜백의 수행 과정 노출 여부를 지정.
#
#
# ##### 3) ModelCheckpoint()
#
# 지정한 평가지표를 기준으로 가장 뛰어난 성능을 보여주는 모델을 저장 할 때 사용
#
# ```python
# ModelCheckpoint(filepath, monitor='평가지표', verbose=1, save_best_only=True|False, save_weights_only=False)
# ```
#
# - filepath: 모델의 저장 경로를 지정
# - save_best_only: True인 경우, 가장 성능이 뛰어난 모델만 저장. 그보다 좋지 않은 모델의 경우는 덮어쓰지 않는다.
# - save_weights_only: 모델의 가중치만 저장

# %%
# %%time
# 파일이 저장될 경로(폴더) 지정 (한글,공백,점(.)이 포함되어 있을 경우 에러 발생함)
checkpoint_path = "E:\\DataScience\MainCourse\\tensorflow_checkpoint\\model04-cp-{epoch:04d}-ckpt.keras"

result = model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=500, verbose=0, callbacks=[
    EarlyStopping(monitor='val_loss', patience=10, verbose=0),
    ReduceLROnPlateau(monitor= "val_loss", patience=3, factor = 0.1, min_lr=0.0001, verbose=0),
    ModelCheckpoint(filepath=checkpoint_path, monitor='val_loss', verbose=1, save_best_only=True)
])

evaluate1 = model.evaluate(x_train, y_train)
print("최종 훈련 손실률: %f, 최종 훈련 절대오차: %f" % (evaluate1[0], evaluate1[1]))

evaluate2 = model.evaluate(x_test, y_test)
print("최종 검증 손실률: %f, 최종 검증 절대오차: %f" % (evaluate2[0], evaluate2[1]))

result_df = DataFrame(result.history)
result_df["epochs"] = result_df.index + 1
result_df.set_index('epochs', inplace=True)
result_df
# Out:
# Epoch 1: val_loss improved from inf to 193897.17188, saving model to E:\DataScience\MainCourse\tensorflow_checkpoint\model04-cp-0001-ckpt.keras
#
# Epoch 2: val_loss improved from 193897.17188 to 193861.62500, saving model to E:\DataScience\MainCourse\tensorflow_checkpoint\model04-cp-0002-ckpt.keras
#
# Epoch 3: val_loss improved from 193861.62500 to 193823.73438, saving model to E:\DataScience\MainCourse\tensorflow_checkpoint\model04-cp-0003-ckpt.keras
#
# Epoch 4: val_loss improved from 193823.73438 to 193784.04688, saving model to E:\DataScience\MainCourse\tensorflow_checkpoint\model04-cp-0004-ckpt.keras
#
# Epoch 5: val_loss improved from 193784.04688 to 193744.06250, saving model to E:\DataScience\MainCourse\tensorflow_checkpoint\model04-cp-0005-ckpt.keras
#
# Epoch 6: val_loss improved from 193744.06250 to 193702.92188, saving model to E:\DataScience\MainCourse\tensorflow_checkpoint\model04-cp-0006-ckpt.keras
#
# Epoch 7: val_loss improved from 193702.92188 to 193659.51562, saving model to E:\DataScience\MainCourse\tensorflow_checkpoint\model04-cp-0007-ckpt.keras
#
# Epoch 8: val_loss improved from 193659.51562 to 193613.25000, saving model to E:\DataScience\MainCourse\tensorflow_checkpoint\model04-cp-0008-ckpt.keras
#
# Epoch 9: val_loss improved from 193613.25000 to 193564.60938, saving model to E:\DataScience\MainCourse\tensorflow_checkpoint\model04-cp-0009-ckpt.keras
#
# Epoch 10: val_loss improved from 193564.60938 to 193513.95312, saving model to E:\DataScience\MainCourse\tensorflow_checkpoint\model04-cp-0010-ckpt.keras
#
# Epoch 11: val_loss improved from 193513.95312 to 193459.76562, saving model to E:\DataScience\MainCourse\tensorflow_checkpoint\model04-cp-0011-ckpt.keras
#
# Epoch 12: val_loss improved from 193459.76562 to 193401.37500, saving model to E:\DataScience\MainCourse\tensorflow_checkpoint\model04-cp-0012-ckpt.keras
#
# Epoch 13: val_loss improved from 193401.37500 to 193337.23438, saving model to E:\DataScience\MainCourse\tensorflow_checkpoint\model04-cp-0013-ckpt.keras
#
# Epoch 14: val_loss improved from 193337.23438 to 193267.75000, saving model to E:\DataScience\MainCourse\tensorflow_checkpoint\model04-cp-0014-ckpt.keras
#
# Epoch 15: val_loss improved from 193267.75000 to 193193.10938, saving model to E:\DataScience\MainCourse\tensorflow_checkpoint\model04-cp-0015-ckpt.keras
#
# Epoch 16: val_loss improved from 193193.10938 to 193112.04688, saving model to E:\DataScience\MainCourse\tensorflow_checkpoint\model04-cp-0016-ckpt.keras
#
# Epoch 17: val_loss improved from 193112.04688 to 193024.39062, saving model to E:\DataScience\MainCourse\tensorflow_checkpoint\model04-cp-0017-ckpt.keras
#
# Epoch 18: val_loss improved from 193024.39062 to 192930.37500, saving model to E:\DataScience\MainCourse\tensorflow_checkpoint\model04-cp-0018-ckpt.keras
#
# Epoch 19: val_loss improved from 192930.37500 to 192828.64062, saving model to E:\DataScience\MainCourse\tensorflow_checkpoint\model04-cp-0019-ckpt.keras
#
# Epoch 20: val_loss improved from 192828.64062 to 192719.81250, saving model to E:\DataScience\MainCourse\tensorflow_checkpoint\model04-cp-0020-ckpt.keras
#
# Epoch 21: val_loss improved from 192719.81250 to 192603.67188, saving model to E:\DataScience\MainCourse\tensorflow_checkpoint\model04-cp-0021-ckpt.keras
#
# Epoch 22: val_loss improved from 192603.67188 to 192475.70312, saving model to E:\DataScience\MainCourse\tensorflow_checkpoint\model04-cp-0022-ckpt.keras
#
# Epoch 23: val_loss improved from 192475.70312 to 192335.89062, saving model to E:\DataScience\MainCourse\tensorflow_checkpoint\model04-cp-0023-ckpt.keras
#
# Epoch 24: val_loss improved from 192335.89062 to 192185.07812, saving model to E:\DataScience\MainCourse\tensorflow_checkpoint\model04-cp-0024-ckpt.keras
#
# Epoch 25: val_loss improved from 192185.07812 to 192022.62500, saving model to E:\DataScience\MainCourse\tensorflow_checkpoint\model04-cp-0025-ckpt.keras
#
# Epoch 26: val_loss improved from 192022.62500 to 191847.17188, saving model to E:\DataScience\MainCourse\tensorflow_checkpoint\model04-cp-0026-ckpt.keras
#
# Epoch 27: val_loss improved from 191847.17188 to 191655.48438, saving model to E:\DataScience\MainCourse\tensorflow_checkpoint\model04-cp-0027-ckpt.keras
#
# Epoch 28: val_loss improved from 191655.48438 to 191447.00000, saving model to E:\DataScience\MainCourse\tensorflow_checkpoint\model04-cp-0028-ckpt.keras
#
# Epoch 29: val_loss improved from 191447.00000 to 191220.00000, saving model to E:\DataScience\MainCourse\tensorflow_checkpoint\model04-cp-0029-ckpt.keras
#
# Epoch 30: val_loss improved from 191220.00000 to 190965.62500, saving model to E:\DataScience\MainCourse\tensorflow_checkpoint\model04-cp-0030-ckpt.keras
#
# Epoch 31: val_loss improved from 190965.62500 to 190682.67188, saving model to E:\DataScience\MainCourse\tensorflow_checkpoint\model04-cp-0031-ckpt.keras
#
# Epoch 32: val_loss improved from 190682.67188 to 190371.70312, saving model to E:\DataScience\MainCourse\tensorflow_checkpoint\model04-cp-0032-ckpt.keras
#
# Epoch 33: val_loss improved from 190371.70312 to 190030.25000, saving model to E:\DataScience\MainCourse\tensorflow_checkpoint\model04-cp-0033-ckpt.keras
#
# Epoch 34: val_loss improved from 190030.25000 to 189657.79688, saving model to E:\DataScience\MainCourse\tensorflow_checkpoint\model04-cp-0034-ckpt.keras
#
# Epoch 35: val_loss improved from 189657.79688 to 189253.39062, saving model to E:\DataScience\MainCourse\tensorflow_checkpoint\model04-cp-0035-ckpt.keras
#
# Epoch 36: val_loss improved from 189253.39062 to 188814.32812, saving model to E:\DataScience\MainCourse\tensorflow_checkpoint\model04-cp-0036-ckpt.keras
#
# Epoch 37: val_loss improved from 188814.32812 to 188337.37500, saving model to E:\DataScience\MainCourse\tensorflow_checkpoint\model04-cp-0037-ckpt.keras
#
# Epoch 38: val_loss improved from 188337.37500 to 187819.32812, saving model to E:\DataScience\MainCourse\tensorflow_checkpoint\model04-cp-0038-ckpt.keras
#
# Epoch 39: val_loss improved from 187819.32812 to 187257.42188, saving model to E:\DataScience\MainCourse\tensorflow_checkpoint\model04-cp-0039-ckpt.keras
#
# Epoch 40: val_loss improved from 187257.42188 to 186651.45312, saving model to E:\DataScience\MainCourse\tensorflow_checkpoint\model04-cp-0040-ckpt.keras
#
# Epoch 41: val_loss improved from 186651.45312 to 185996.26562, saving model to E:\DataScience\MainCourse\tensorflow_checkpoint\model04-cp-0041-ckpt.keras
#
# Epoch 42: val_loss improved from 185996.26562 to 185295.76562, saving model to E:\DataScience\MainCourse\tensorflow_checkpoint\model04-cp-0042-ckpt.keras
#
# Epoch 43: val_loss improved from 185295.76562 to 184541.32812, saving model to E:\DataScience\MainCourse\tensorflow_checkpoint\model04-cp-0043-ckpt.keras
#
# Epoch 44: val_loss improved from 184541.32812 to 183732.70312, saving model to E:\DataScience\MainCourse\tensorflow_checkpoint\model04-cp-0044-ckpt.keras
#
# Epoch 45: val_loss improved from 183732.70312 to 182861.85938, saving model to E:\DataScience\MainCourse\tensorflow_checkpoint\model04-cp-0045-ckpt.keras
#
# Epoch 46: val_loss improved from 182861.85938 to 181934.25000, saving model to E:\DataScience\MainCourse\tensorflow_checkpoint\model04-cp-0046-ckpt.keras
#
# Epoch 47: val_loss improved from 181934.25000 to 180933.79688, saving model to E:\DataScience\MainCourse\tensorflow_checkpoint\model04-cp-0047-ckpt.keras
#
# Epoch 48: val_loss improved from 180933.79688 to 179850.42188, saving model to E:\DataScience\MainCourse\tensorflow_checkpoint\model04-cp-0048-ckpt.keras
#
# Epoch 49: val_loss improved from 179850.42188 to 178689.06250, saving model to E:\DataScience\MainCourse\tensorflow_checkpoint\model04-cp-0049-ckpt.keras
#
# Epoch 50: val_loss improved from 178689.06250 to 177436.79688, saving model to E:\DataScience\MainCourse\tensorflow_checkpoint\model04-cp-0050-ckpt.keras
#
# Epoch 51: val_loss improved from 177436.79688 to 176098.17188, saving model to E:\DataScience\MainCourse\tensorflow_checkpoint\model04-cp-0051-ckpt.keras
#
# Epoch 52: val_loss improved from 176098.17188 to 174670.82812, saving model to E:\DataScience\MainCourse\tensorflow_checkpoint\model04-cp-0052-ckpt.keras
#
# Epoch 53: val_loss improved from 174670.82812 to 173145.68750, saving model to E:\DataScience\MainCourse\tensorflow_checkpoint\model04-cp-0053-ckpt.keras
#
# Epoch 54: val_loss improved from 173145.68750 to 171530.89062, saving model to E:\DataScience\MainCourse\tensorflow_checkpoint\model04-cp-0054-ckpt.keras
#
# Epoch 55: val_loss improved from 171530.89062 to 169824.42188, saving model to E:\DataScience\MainCourse\tensorflow_checkpoint\model04-cp-0055-ckpt.keras
#
# Epoch 56: val_loss improved from 169824.42188 to 168003.37500, saving model to E:\DataScience\MainCourse\tensorflow_checkpoint\model04-cp-0056-ckpt.keras
#
# Epoch 57: val_loss improved from 168003.37500 to 166039.57812, saving model to E:\DataScience\MainCourse\tensorflow_checkpoint\model04-cp-0057-ckpt.keras
#
# Epoch 58: val_loss improved from 166039.57812 to 163952.43750, saving model to E:\DataScience\MainCourse\tensorflow_checkpoint\model04-cp-0058-ckpt.keras
#
# Epoch 59: val_loss improved from 163952.43750 to 161735.29688, saving model to E:\DataScience\MainCourse\tensorflow_checkpoint\model04-cp-0059-ckpt.keras
#
# Epoch 60: val_loss improved from 161735.29688 to 159351.73438, saving model to E:\DataScience\MainCourse\tensorflow_checkpoint\model04-cp-0060-ckpt.keras
#
# Epoch 61: val_loss improved from 159351.73438 to 156819.89062, saving model to E:\DataScience\MainCourse\tensorflow_checkpoint\model04-cp-0061-ckpt.keras
#
# Epoch 62: val_loss improved from 156819.89062 to 154128.06250, saving model to E:\DataScience\MainCourse\tensorflow_checkpoint\model04-cp-0062-ckpt.keras
#
# Epoch 63: val_loss improved from 154128.06250 to 151339.95312, saving model to E:\DataScience\MainCourse\tensorflow_checkpoint\model04-cp-0063-ckpt.keras
#
# Epoch 64: val_loss improved from 151339.95312 to 148335.89062, saving model to E:\DataScience\MainCourse\tensorflow_checkpoint\model04-cp-0064-ckpt.keras
#
# Epoch 65: val_loss improved from 148335.89062 to 145181.35938, saving model to E:\DataScience\MainCourse\tensorflow_checkpoint\model04-cp-0065-ckpt.keras
#
# Epoch 66: val_loss improved from 145181.35938 to 141819.51562, saving model to E:\DataScience\MainCourse\tensorflow_checkpoint\model04-cp-0066-ckpt.keras
#
# Epoch 67: val_loss improved from 141819.51562 to 138343.23438, saving model to E:\DataScience\MainCourse\tensorflow_checkpoint\model04-cp-0067-ckpt.keras
#
# Epoch 68: val_loss improved from 138343.23438 to 134730.01562, saving model to E:\DataScience\MainCourse\tensorflow_checkpoint\model04-cp-0068-ckpt.keras
#
# Epoch 69: val_loss improved from 134730.01562 to 130960.81250, saving model to E:\DataScience\MainCourse\tensorflow_checkpoint\model04-cp-0069-ckpt.keras
#
# Epoch 70: val_loss improved from 130960.81250 to 127021.18750, saving model to E:\DataScience\MainCourse\tensorflow_checkpoint\model04-cp-0070-ckpt.keras
#
# Epoch 71: val_loss improved from 127021.18750 to 122907.03906, saving model to E:\DataScience\MainCourse\tensorflow_checkpoint\model04-cp-0071-ckpt.keras
#
# Epoch 72: val_loss improved from 122907.03906 to 118662.62500, saving model to E:\DataScience\MainCourse\tensorflow_checkpoint\model04-cp-0072-ckpt.keras
#
# Epoch 73: val_loss improved from 118662.62500 to 114315.71875, saving model to E:\DataScience\MainCourse\tensorflow_checkpoint\model04-cp-0073-ckpt.keras
#
# Epoch 74: val_loss improved from 114315.71875 to 109834.75000, saving model to E:\DataScience\MainCourse\tensorflow_checkpoint\model04-cp-0074-ckpt.keras
#
# Epoch 75: val_loss improved from 109834.75000 to 105213.69531, saving model to E:\DataScience\MainCourse\tensorflow_checkpoint\model04-cp-0075-ckpt.keras
#
# Epoch 76: val_loss improved from 105213.69531 to 100624.46875, saving model to E:\DataScience\MainCourse\tensorflow_checkpoint\model04-cp-0076-ckpt.keras
#
# Epoch 77: val_loss improved from 100624.46875 to 96079.68750, saving model to E:\DataScience\MainCourse\tensorflow_checkpoint\model04-cp-0077-ckpt.keras
#
# Epoch 78: val_loss improved from 96079.68750 to 91509.89844, saving model to E:\DataScience\MainCourse\tensorflow_checkpoint\model04-cp-0078-ckpt.keras
#
# Epoch 79: val_loss improved from 91509.89844 to 86802.13281, saving model to E:\DataScience\MainCourse\tensorflow_checkpoint\model04-cp-0079-ckpt.keras
#
# Epoch 80: val_loss improved from 86802.13281 to 81917.15625, saving model to E:\DataScience\MainCourse\tensorflow_checkpoint\model04-cp-0080-ckpt.keras
#
# Epoch 81: val_loss improved from 81917.15625 to 76937.06250, saving model to E:\DataScience\MainCourse\tensorflow_checkpoint\model04-cp-0081-ckpt.keras
#
# Epoch 82: val_loss improved from 76937.06250 to 71921.94531, saving model to E:\DataScience\MainCourse\tensorflow_checkpoint\model04-cp-0082-ckpt.keras
#
# Epoch 83: val_loss improved from 71921.94531 to 66970.31250, saving model to E:\DataScience\MainCourse\tensorflow_checkpoint\model04-cp-0083-ckpt.keras
#
# Epoch 84: val_loss improved from 66970.31250 to 62112.36328, saving model to E:\DataScience\MainCourse\tensorflow_checkpoint\model04-cp-0084-ckpt.keras
#
# Epoch 85: val_loss improved from 62112.36328 to 57276.46875, saving model to E:\DataScience\MainCourse\tensorflow_checkpoint\model04-cp-0085-ckpt.keras
#
# Epoch 86: val_loss improved from 57276.46875 to 52452.43750, saving model to E:\DataScience\MainCourse\tensorflow_checkpoint\model04-cp-0086-ckpt.keras
#
# Epoch 87: val_loss improved from 52452.43750 to 47690.19141, saving model to E:\DataScience\MainCourse\tensorflow_checkpoint\model04-cp-0087-ckpt.keras
#
# Epoch 88: val_loss improved from 47690.19141 to 43015.30078, saving model to E:\DataScience\MainCourse\tensorflow_checkpoint\model04-cp-0088-ckpt.keras
#
# Epoch 89: val_loss improved from 43015.30078 to 38547.12891, saving model to E:\DataScience\MainCourse\tensorflow_checkpoint\model04-cp-0089-ckpt.keras
#
# Epoch 90: val_loss improved from 38547.12891 to 34283.87109, saving model to E:\DataScience\MainCourse\tensorflow_checkpoint\model04-cp-0090-ckpt.keras
#
# Epoch 91: val_loss improved from 34283.87109 to 30188.80664, saving model to E:\DataScience\MainCourse\tensorflow_checkpoint\model04-cp-0091-ckpt.keras
#
# Epoch 92: val_loss improved from 30188.80664 to 26359.17188, saving model to E:\DataScience\MainCourse\tensorflow_checkpoint\model04-cp-0092-ckpt.keras
#
# Epoch 93: val_loss improved from 26359.17188 to 22882.77539, saving model to E:\DataScience\MainCourse\tensorflow_checkpoint\model04-cp-0093-ckpt.keras
#
# Epoch 94: val_loss improved from 22882.77539 to 19738.54102, saving model to E:\DataScience\MainCourse\tensorflow_checkpoint\model04-cp-0094-ckpt.keras
#
# Epoch 95: val_loss improved from 19738.54102 to 16956.08594, saving model to E:\DataScience\MainCourse\tensorflow_checkpoint\model04-cp-0095-ckpt.keras
#
# Epoch 96: val_loss improved from 16956.08594 to 14518.96777, saving model to E:\DataScience\MainCourse\tensorflow_checkpoint\model04-cp-0096-ckpt.keras
#
# Epoch 97: val_loss improved from 14518.96777 to 12488.32520, saving model to E:\DataScience\MainCourse\tensorflow_checkpoint\model04-cp-0097-ckpt.keras
#
# Epoch 98: val_loss improved from 12488.32520 to 10856.36426, saving model to E:\DataScience\MainCourse\tensorflow_checkpoint\model04-cp-0098-ckpt.keras
#
# Epoch 99: val_loss improved from 10856.36426 to 9569.71680, saving model to E:\DataScience\MainCourse\tensorflow_checkpoint\model04-cp-0099-ckpt.keras
#
# Epoch 100: val_loss improved from 9569.71680 to 8622.86426, saving model to E:\DataScience\MainCourse\tensorflow_checkpoint\model04-cp-0100-ckpt.keras
#
# Epoch 101: val_loss improved from 8622.86426 to 7959.59131, saving model to E:\DataScience\MainCourse\tensorflow_checkpoint\model04-cp-0101-ckpt.keras
#
# Epoch 102: val_loss improved from 7959.59131 to 7541.37109, saving model to E:\DataScience\MainCourse\tensorflow_checkpoint\model04-cp-0102-ckpt.keras
#
# Epoch 103: val_loss improved from 7541.37109 to 7314.59229, saving model to E:\DataScience\MainCourse\tensorflow_checkpoint\model04-cp-0103-ckpt.keras
#
# Epoch 104: val_loss improved from 7314.59229 to 7220.01416, saving model to E:\DataScience\MainCourse\tensorflow_checkpoint\model04-cp-0104-ckpt.keras
#
# Epoch 105: val_loss did not improve from 7220.01416
#
# Epoch 106: val_loss did not improve from 7220.01416
#
# Epoch 107: val_loss did not improve from 7220.01416
#
# Epoch 108: val_loss did not improve from 7220.01416
#
# Epoch 109: val_loss did not improve from 7220.01416
#
# Epoch 110: val_loss did not improve from 7220.01416
#
# Epoch 111: val_loss did not improve from 7220.01416
#
# Epoch 112: val_loss did not improve from 7220.01416
#
# Epoch 113: val_loss did not improve from 7220.01416
#
# Epoch 114: val_loss did not improve from 7220.01416
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 6377.6968 - mae: 62.9993
# 최종 훈련 손실률: 7131.724609, 최종 훈련 절대오차: 65.565193
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 7306.2788 - mae: 69.5295
# 최종 검증 손실률: 7306.278809, 최종 검증 절대오차: 69.529503
# CPU times: total: 15.7 s
# Wall time: 24 s
#                  loss         mae       val_loss     val_mae  learning_rate
# epochs
# 1       283689.593750  391.108398  193897.171875  348.271851         0.0010
# 2       283637.062500  391.064056  193861.625000  348.230743         0.0010
# 3       283590.937500  391.019501  193823.734375  348.186798         0.0010
# 4       283537.531250  390.969818  193784.046875  348.140228         0.0010
# 5       283483.781250  390.919464  193744.062500  348.092041         0.0010
# ...               ...         ...            ...         ...            ...
# 110       7257.468750   66.139473    7356.552246   69.643806         0.0001
# 111       7236.770020   66.038040    7346.246094   69.631828         0.0001
# 112       7205.933105   65.894310    7333.859863   69.605263         0.0001
# 113       7180.437988   65.782684    7320.264160   69.569397         0.0001
# 114       7151.973145   65.655785    7306.278809   69.529503         0.0001
#
# [114 rows x 5 columns]

# %% [markdown]
# ### [3] 훈련 결과 시각화

# %%
fig, ax = plt.subplots(1, 2, figsize=(15, 5), dpi=150)
result_df.plot(y=['loss', 'val_loss'], ax=ax[0])
result_df.plot(y=['mae', 'val_mae'], ax=ax[1])
ax[0].set_title('loss')
ax[1].set_title('mae')
ax[0].grid()
ax[1].grid()
plt.show()
plt.close()

# %% [markdown]
# ## #04. 예측 결과 활용
#
# ### [1] 예측치 구하기

# %%
pred =  model.predict(x_test, verbose=0)
pred
# Out:
# array([[680.2127 ],
#        [191.2788 ],
#        [755.43396],
#        [148.26152],
#        [162.60194],
#        [220.21638],
#        [161.07228],
#        [679.61334],
#        [926.74866],
#        [300.49664],
#        [197.95085],
#        [167.91878]], dtype=float32)

# %% [markdown]
# ### [2] 결과 데이터 셋 구성

# %%
kdf = DataFrame({
    '길이': x_test['길이'],
    '실제값': y_test,
    '예측값' : pred.flatten()
})

kdf['오차'] = kdf['실제값']-kdf['예측값']

my_pretty_table(kdf)
# Out:
# +----+------------+----------+----------+-----------+
# |    |       길이 |   실제값 |   예측값 |      오차 |
# |----+------------+----------+----------+-----------|
# | 45 |    1.20816 |      650 |  680.213 |  -30.2127 |
# | 33 | -0.0476513 |      250 |  191.279 |   58.7212 |
# | 40 |   0.935156 |      685 |  755.434 |   -70.434 |
# | 26 |  -0.364334 |      188 |  148.262 |   39.7385 |
# | 11 |  -0.757457 |      115 |  162.602 |  -47.6019 |
# |  2 |   -1.41266 |       40 |  220.216 |  -180.216 |
# | 32 | -0.0476513 |      265 |  161.072 |   103.928 |
# | 43 |   0.989757 |      690 |  679.613 |   10.3867 |
# | 46 |    1.20816 |      820 |  926.749 |  -106.749 |
# | 30 | -0.0694914 |      300 |  300.497 | -0.496643 |
# |  4 |   -1.15058 |       70 |  197.951 |  -127.951 |
# | 10 |  -0.757457 |      110 |  167.919 |  -57.9188 |
# +----+------------+----------+----------+-----------+

# %% [markdown]
# ### [3] 관측치와 예측치 비교 시각화

# %%
fig = plt.figure(figsize=(10, 5), dpi=150)
ax = fig.gca()

sb.regplot(data=kdf, x='길이', y='실제값', label='실제값', ax=ax)
sb.regplot(data=kdf, x='길이', y='예측값', label='예측값', ax=ax)
ax.legend()
ax.grid()
plt.show()
plt.close()
