# %%
# %load_ext autoreload
# %autoreload 2

from hossam.util import *
from hossam.plot import *
from hossam.tensor import *
from pandas import merge, read_excel, pivot_table, melt, to_datetime, to_timedelta, DateOffset, Timestamp, Period, Series
import numpy as np
import re

# %%
df1  =my_read_excel("통합6-1.xlsx")
df1['연월'] = to_datetime(df1['연월'], format="%Y-%m")
df2 =df1.drop(['매출액','골프전환','골프전환2','골프매출','헬스매출','환불사용금매출','미수액'], axis=1)
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6309 entries, 0 to 6308
# Data columns (total 24 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   회원카드번호   6309 non-null   int64
#  1   연월       6309 non-null   datetime64[ns]
#  2   등록명      6309 non-null   object
#  3   매출액      6309 non-null   int64
#  4   골프전환     6309 non-null   int64
#  5   골프매출     6309 non-null   int64
#  6   헬스매출     6309 non-null   int64
#  7   환불사용금매출  6309 non-null   int64
#  8   미수액      6309 non-null   int64
#  9   개월수      6309 non-null   int64
#  10  종료시점     6309 non-null   datetime64[ns]
#  11  최초등록월    6309 non-null   datetime64[ns]
#  12  환불여부     318 non-null    float64
#  13  골프전환2    52 non-null     float64
#  14  양도       538 non-null    float64
#  15  휴면가능     6309 non-null   int64
#  16  휴면반영     5505 non-null   datetime64[ns]
#  17  거래순서     6309 non-null   int64
#  18  마지막거래    6309 non-null   int64
#  19  잔여개월수    6309 non-null   int64
# ...

# %%
df10  =my_read_excel("통합8-5.xlsx")
df10['연월'] = to_datetime(df10['연월'], format="%Y-%m")
df11 = df10.drop(['등록명','개월수'], axis=1)
df11.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 35 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  6497 non-null   int64
#  1   회원카드번호      6497 non-null   int64
#  2   연월          6497 non-null   datetime64[ns]
#  3   등록명         6497 non-null   object
#  4   환불내역        543 non-null    object
#  5   요일          1543 non-null   object
#  6   미수액         6497 non-null   int64
#  7   거래일_일       6497 non-null   int64
#  8   환불일_일       6497 non-null   int64
#  9   일일입장        6497 non-null   int64
#  10  분실          6497 non-null   int64
#  11  부가서비스사용     6497 non-null   int64
#  12  레슨여부        6497 non-null   int64
#  13  매출액         6497 non-null   int64
#  14  개월수         6497 non-null   int64
#  15  골프전환        6497 non-null   int64
#  16  단체회원        6497 non-null   int64
#  17  골프매출        6497 non-null   int64
#  18  라카매출        6497 non-null   int64
# ...

# %%
df11['GX매출'].unique()
# Out:
# array([     0, 480000,  60000, 470000,  30000, 440000, 888000,  50000,
#        150000], dtype=int64)

# %%
merged_df1 = merge(df2, df11, on=['회원카드번호','연월'])
merged_df1
# Out:
#         회원카드번호         연월 등록명  개월수       종료시점      최초등록월  환불여부  양도  휴면가능  \
# 0     12131325 2020-09-01  헬스   12 2021-09-01 2020-09-01   NaN NaN     2
# 1     13110008 2021-05-01  골프   12 2022-06-01 2021-05-01   NaN NaN     2
# 2     13110008 2022-06-01  골프   12 2023-08-01 2021-05-01   NaN NaN     2
# 3     13110008 2023-11-01  골프   12 2024-11-01 2021-05-01   NaN NaN     2
# 4     13110009 2020-10-01  헬스   12 2021-12-01 2020-10-01   NaN NaN     2
# ...        ...        ...  ..  ...        ...        ...   ...  ..   ...
# 6304  23120075 2023-12-01  골프   10 2024-10-01 2023-12-01   NaN NaN     0
# 6305  23120076 2023-12-01  헬스   10 2024-10-01 2023-12-01   NaN NaN     0
# 6306  23120077 2023-12-01  헬스   10 2024-10-01 2023-12-01   NaN NaN     0
# 6307  24010001 2023-12-01  헬스   10 2024-10-01 2023-12-01   NaN NaN     0
# 6308  24010003 2022-01-01  헬스   10 2022-11-01 2022-01-01   NaN NaN     0
#
#            휴면반영  ...  환불사용금매출    의류매출  분실매출  GX매출  상환액매출  입회비매출  예치금매출  FC 성별  \
# ...

# %%
merged_df1.to_excel('통합9-2.xlsx', index=False)
