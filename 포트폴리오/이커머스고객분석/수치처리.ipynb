# %%
from pandas import read_excel, merge, concat
from numpy import array
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 from pandas import read_excel, merge, concat, to_excel
#       2 from numpy import array
#
# ImportError: cannot import name 'to_excel' from 'pandas' (c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\__init__.py)

# %%
origin = read_excel("musinsadata_rabelling.xlsx")
origin
# Out:
#          상품번호                                      상품명  ...     분류   성별
# 0     2037173                        베이직 푸퍼_SPJPE11C11  ...   62.0  1.0
# 1     1163169                  삼바 OG - 화이트:블랙 / B75806  ...  108.0  0.0
# 2     1178135                  삼바 OG - 블랙:화이트 / B75807  ...  108.0  0.0
# 3      452483                                솔리드 무톤 자켓  ...   31.0  0.0
# 4     2782764  OVERSIZED CASHMERE BALMACAAN COAT BLACK  ...    4.0  1.0
# ...       ...                                      ...  ...    ...  ...
# 7678  2697817                       [세트]블룸 트레이닝 셋업-그레이  ...   26.0  0.0
# 7679  2757362                    TISNVRHT Hoodie Black  ...  122.0  0.0
# 7680  3220337               [리뉴얼] 나일론 카고 밴딩팬츠_차콜_PL170  ...  102.0  0.0
# 7681  3436582     블랙 와이드핏 밴딩 윈터 테리 니트 팬츠 (TNPA3F104BK)  ...   93.0  1.0
# 7682  2772719                         유틸리티 후드 숏 패딩-베이지  ...   62.0  0.0
#
# [7683 rows x 27 columns]

# %%
copy = origin.copy()
copy
# Out:
#          상품번호                                      상품명  ...     분류   성별
# 0     2037173                        베이직 푸퍼_SPJPE11C11  ...   62.0  1.0
# 1     1163169                  삼바 OG - 화이트:블랙 / B75806  ...  108.0  0.0
# 2     1178135                  삼바 OG - 블랙:화이트 / B75807  ...  108.0  0.0
# 3      452483                                솔리드 무톤 자켓  ...   31.0  0.0
# 4     2782764  OVERSIZED CASHMERE BALMACAAN COAT BLACK  ...    4.0  1.0
# ...       ...                                      ...  ...    ...  ...
# 7678  2697817                       [세트]블룸 트레이닝 셋업-그레이  ...   26.0  0.0
# 7679  2757362                    TISNVRHT Hoodie Black  ...  122.0  0.0
# 7680  3220337               [리뉴얼] 나일론 카고 밴딩팬츠_차콜_PL170  ...  102.0  0.0
# 7681  3436582     블랙 와이드핏 밴딩 윈터 테리 니트 팬츠 (TNPA3F104BK)  ...   93.0  1.0
# 7682  2772719                         유틸리티 후드 숏 패딩-베이지  ...   62.0  0.0
#
# [7683 rows x 27 columns]

# %%
import pandas as pd
copy['조회수'] = copy['총 조회수'] - copy['비로그인_v']
# Assuming 'copy' is your DataFrame
# copy['조회수(19~23세)'] = copy['조회수(19~23세)'] / copy['총 조회수']
# copy['조회수(18세이하)'] = copy['조회수(18세이하)'] / copy['총 조회수']
# copy['조회수(24~28세)'] = copy['조회수(24~28세)'] / copy['총 조회수']
# copy['조회수(29~33세)'] = copy['조회수(29~33세)'] / copy['총 조회수']
# copy['조회수(34~39세)'] = copy['조회수(34~39세)'] / copy['총 조회수']
# copy['조회수(40세이상)'] = copy['조회수(40세이상)'] / copy['총 조회수']
# copy['비로그인_v'] = copy['비로그인_v'] / copy['총 조회수']
copy
# Assuming 'copy' is your DataFrame
copy['조회수(19~23세)'] = copy['조회수(19~23세)'] / copy['조회수']
copy['조회수(18세이하)'] = copy['조회수(18세이하)'] / copy['조회수']
copy['조회수(24~28세)'] = copy['조회수(24~28세)'] / copy['조회수']
copy['조회수(29~33세)'] = copy['조회수(29~33세)'] / copy['조회수']
copy['조회수(34~39세)'] = copy['조회수(34~39세)'] / copy['조회수']
copy['조회수(40세이상)'] = copy['조회수(40세이상)'] / copy['조회수']

# %%
copy
# Out:
#          상품번호                                      상품명  ...   성별     조회수
# 0     2037173                        베이직 푸퍼_SPJPE11C11  ...  1.0  281836
# 1     1163169                  삼바 OG - 화이트:블랙 / B75806  ...  0.0  134648
# 2     1178135                  삼바 OG - 블랙:화이트 / B75807  ...  0.0  132138
# 3      452483                                솔리드 무톤 자켓  ...  0.0  124600
# 4     2782764  OVERSIZED CASHMERE BALMACAAN COAT BLACK  ...  1.0   93709
# ...       ...                                      ...  ...  ...     ...
# 7678  2697817                       [세트]블룸 트레이닝 셋업-그레이  ...  0.0    1825
# 7679  2757362                    TISNVRHT Hoodie Black  ...  0.0    6727
# 7680  3220337               [리뉴얼] 나일론 카고 밴딩팬츠_차콜_PL170  ...  0.0    3151
# 7681  3436582     블랙 와이드핏 밴딩 윈터 테리 니트 팬츠 (TNPA3F104BK)  ...  1.0    1309
# 7682  2772719                         유틸리티 후드 숏 패딩-베이지  ...  0.0   25346
#
# [7683 rows x 28 columns]

# %%
# copy['구매수'] = copy['총 구매수'] - copy['비로그인_p']
# Assuming 'copy' is your DataFrame
# copy['조회수(19~23세)'] = copy['조회수(19~23세)'] / copy['총 조회수']
# copy['조회수(18세이하)'] = copy['조회수(18세이하)'] / copy['총 조회수']
# copy['조회수(24~28세)'] = copy['조회수(24~28세)'] / copy['총 조회수']
# copy['조회수(29~33세)'] = copy['조회수(29~33세)'] / copy['총 조회수']
# copy['조회수(34~39세)'] = copy['조회수(34~39세)'] / copy['총 조회수']
# copy['조회수(40세이상)'] = copy['조회수(40세이상)'] / copy['총 조회수']
# copy['비로그인_v'] = copy['비로그인_v'] / copy['총 조회수']
copy
# Assuming 'copy' is your DataFrame
# copy['구매수(19~23세)'] = copy['구매수(19~23세)'] / copy['구매수']
# copy['구매수(18세이하)'] = copy['구매수(18세이하)'] / copy['구매수']
# copy['구매수(24~28세)'] = copy['구매수(24~28세)'] / copy['구매수']
# copy['구매수(29~33세)'] = copy['구매수(29~33세)'] / copy['구매수']
# copy['구매수(34~39세)'] = copy['구매수(34~39세)'] / copy['구매수']
# copy['구매수(40세이상)'] = copy['구매수(40세이상)'] / copy['구매수']
# copy
# Out:
#          상품번호                                      상품명  ...     조회수    구매수
# 0     2037173                        베이직 푸퍼_SPJPE11C11  ...  281836  75761
# 1     1163169                  삼바 OG - 화이트:블랙 / B75806  ...  134648  16019
# 2     1178135                  삼바 OG - 블랙:화이트 / B75807  ...  132138  15032
# 3      452483                                솔리드 무톤 자켓  ...  124600   9214
# 4     2782764  OVERSIZED CASHMERE BALMACAAN COAT BLACK  ...   93709   4794
# ...       ...                                      ...  ...     ...    ...
# 7678  2697817                       [세트]블룸 트레이닝 셋업-그레이  ...    1825    274
# 7679  2757362                    TISNVRHT Hoodie Black  ...    6727    269
# 7680  3220337               [리뉴얼] 나일론 카고 밴딩팬츠_차콜_PL170  ...    3151   2405
# 7681  3436582     블랙 와이드핏 밴딩 윈터 테리 니트 팬츠 (TNPA3F104BK)  ...    1309    104
# 7682  2772719                         유틸리티 후드 숏 패딩-베이지  ...   25346    255
#
# [7683 rows x 29 columns]

# %%
# copy['구매수'] = copy['총 구매수'] - copy['비로그인_p']
# Assuming 'copy' is your DataFrame
# copy['조회수(19~23세)'] = copy['조회수(19~23세)'] / copy['총 조회수']
# copy['조회수(18세이하)'] = copy['조회수(18세이하)'] / copy['총 조회수']
# copy['조회수(24~28세)'] = copy['조회수(24~28세)'] / copy['총 조회수']
# copy['조회수(29~33세)'] = copy['조회수(29~33세)'] / copy['총 조회수']
# copy['조회수(34~39세)'] = copy['조회수(34~39세)'] / copy['총 조회수']
# copy['조회수(40세이상)'] = copy['조회수(40세이상)'] / copy['총 조회수']
# copy['비로그인_v'] = copy['비로그인_v'] / copy['총 조회수']
# copy
# Assuming 'copy' is your DataFrame
# copy['구매수(19~23세)'] = copy['구매수(19~23세)'] / copy['구매수']
# copy['구매수(18세이하)'] = copy['구매수(18세이하)'] / copy['구매수']
# copy['구매수(24~28세)'] = copy['구매수(24~28세)'] / copy['구매수']
# copy['구매수(29~33세)'] = copy['구매수(29~33세)'] / copy['구매수']
# copy['구매수(34~39세)'] = copy['구매수(34~39세)'] / copy['구매수']
# copy['구매수(40세이상)'] = copy['구매수(40세이상)'] / copy['구매수']
# copy
copy['남성 조회수'] = copy['남성 조회수']/copy['조회수']
copy['여성 조회수'] = copy['여성 조회수']/copy['조회수']
copy['남성 구매수'] = copy['남성 구매수']/copy['구매수']
copy['여성 구매수'] = copy['여성 구매수']/copy['구매수']
copy
# Out:
#          상품번호                                      상품명  ...     조회수    구매수
# 0     2037173                        베이직 푸퍼_SPJPE11C11  ...  281836  75761
# 1     1163169                  삼바 OG - 화이트:블랙 / B75806  ...  134648  16019
# 2     1178135                  삼바 OG - 블랙:화이트 / B75807  ...  132138  15032
# 3      452483                                솔리드 무톤 자켓  ...  124600   9214
# 4     2782764  OVERSIZED CASHMERE BALMACAAN COAT BLACK  ...   93709   4794
# ...       ...                                      ...  ...     ...    ...
# 7678  2697817                       [세트]블룸 트레이닝 셋업-그레이  ...    1825    274
# 7679  2757362                    TISNVRHT Hoodie Black  ...    6727    269
# 7680  3220337               [리뉴얼] 나일론 카고 밴딩팬츠_차콜_PL170  ...    3151   2405
# 7681  3436582     블랙 와이드핏 밴딩 윈터 테리 니트 팬츠 (TNPA3F104BK)  ...    1309    104
# 7682  2772719                         유틸리티 후드 숏 패딩-베이지  ...   25346    255
#
# [7683 rows x 29 columns]

# %%
copy
# Out:
#          상품번호                                      상품명  ...     조회수    구매수
# 0     2037173                        베이직 푸퍼_SPJPE11C11  ...  281836  75761
# 1     1163169                  삼바 OG - 화이트:블랙 / B75806  ...  134648  16019
# 2     1178135                  삼바 OG - 블랙:화이트 / B75807  ...  132138  15032
# 3      452483                                솔리드 무톤 자켓  ...  124600   9214
# 4     2782764  OVERSIZED CASHMERE BALMACAAN COAT BLACK  ...   93709   4794
# ...       ...                                      ...  ...     ...    ...
# 7678  2697817                       [세트]블룸 트레이닝 셋업-그레이  ...    1825    274
# 7679  2757362                    TISNVRHT Hoodie Black  ...    6727    269
# 7680  3220337               [리뉴얼] 나일론 카고 밴딩팬츠_차콜_PL170  ...    3151   2405
# 7681  3436582     블랙 와이드핏 밴딩 윈터 테리 니트 팬츠 (TNPA3F104BK)  ...    1309    104
# 7682  2772719                         유틸리티 후드 숏 패딩-베이지  ...   25346    255
#
# [7683 rows x 29 columns]

# %%
copy.to_excel("musinsadata_login_ratio.xlsx")
