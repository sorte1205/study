# %%
import sys
import os
work_path = os.path.abspath(os.path.join(os.getcwd(), "../.."))
sys.path.append(work_path)

from help_a.util import *
from help_a.plot import *
from help_a.analysis import *
from help_a.classification import *

# %%
my_read_csv("Sample_지역별가맹점매출.csv", encoding= "euc-kr")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   strd_yymm     50 non-null     int64
#  1   mer_zp        50 non-null     int64
#  2   mer_tpbuz_cd  50 non-null     int64
#  3   ctpr_nm       50 non-null     object
#  4   ccg_nm        50 non-null     object
#  5   town_nm       0 non-null      float64
#  6   mer_tpbuz_nm  50 non-null     object
#  7   sale_amt      50 non-null     int64
# dtypes: float64(1), int64(4), object(3)
# memory usage: 3.3+ KB
# None
#
# 데이터프레임 상위 5개 행
# +----+-------------+----------+----------------+------------+----------+-----------+----------------+------------+
# |    |   strd_yymm |   mer_zp |   mer_tpbuz_cd | ctpr_nm    | ccg_nm   |   town_nm | mer_tpbuz_nm   |   sale_amt |
# |----+-------------+----------+----------------+------------+----------+-----------+----------------+------------|
# |  0 |      202011 |     1002 |           4010 | 서울특별시 | 강북구   |       nan | 편 의 점       |      96844 |
# |  1 |      202011 |     1004 |           4020 | 서울특별시 | 강북구   |       nan | 슈퍼 마켓      |       8817 |
# |  2 |      202011 |     1005 |           4010 | 서울특별시 | 강북구   |       nan | 편 의 점       |      14564 |
# |  3 |      202011 |     1006 |           4010 | 서울특별시 | 강북구   |       nan | 편 의 점       |      33400 |
# |  4 |      202011 |     1010 |           4010 | 서울특별시 | 강북구   |       nan | 편 의 점       |       5100 |
# +----+-------------+----------+----------------+------------+----------+-----------+----------------+------------+
#
# 데이터프레임 하위 5개 행
# +----+-------------+----------+----------------+------------+----------+-----------+----------------+------------+
# |    |   strd_yymm |   mer_zp |   mer_tpbuz_cd | ctpr_nm    | ccg_nm   |   town_nm | mer_tpbuz_nm   |   sale_amt |
# |----+-------------+----------+----------------+------------+----------+-----------+----------------+------------|
# | 45 |      202011 |     1079 |           4020 | 서울특별시 | 강북구   |       nan | 슈퍼 마켓      |      21410 |
# | 46 |      202011 |     1080 |           4010 | 서울특별시 | 강북구   |       nan | 편 의 점       |     205291 |
# | 47 |      202011 |     1080 |           4020 | 서울특별시 | 강북구   |       nan | 슈퍼 마켓      |      23020 |
# | 48 |      202011 |     1081 |           4010 | 서울특별시 | 강북구   |       nan | 편 의 점       |      27293 |
# | 49 |      202011 |     1090 |           4020 | 서울특별시 | 강북구   |       nan | 슈퍼 마켓      |      43910 |
# +----+-------------+----------+----------------+------------+----------+-----------+----------------+------------+
#
# 기술통계
# +--------------+---------+---------+---------+--------+---------+--------+---------+--------+-------+
# |              |   count |    mean |     std |    min |     25% |    50% |     75% |    max |   nan |
# |--------------+---------+---------+---------+--------+---------+--------+---------+--------+-------|
# | strd_yymm    |      50 |  202011 |       0 | 202011 |  202011 | 202011 |  202011 | 202011 |     0 |
# | mer_zp       |      50 |  1048.2 | 23.8173 |   1002 | 1029.25 |   1050 |  1065.5 |   1090 |     0 |
# | mer_tpbuz_cd |      50 | 4296.16 | 1134.06 |   2199 |    4010 |   4010 |    4020 |   8006 |     0 |
# | town_nm      |       0 |     nan |     nan |    nan |     nan |    nan |     nan |    nan |    50 |
# | sale_amt     |      50 |   38942 | 60071.4 |   3667 |  8605.5 |  17960 | 33674.5 | 284938 |     0 |
# +--------------+---------+---------+---------+--------+---------+--------+---------+--------+-------+
#     strd_yymm  mer_zp  mer_tpbuz_cd ctpr_nm ccg_nm  town_nm mer_tpbuz_nm  \
# 0      202011    1002          4010   서울특별시    강북구      NaN        편 의 점
# 1      202011    1004          4020   서울특별시    강북구      NaN        슈퍼 마켓
# 2      202011    1005          4010   서울특별시    강북구      NaN        편 의 점
# 3      202011    1006          4010   서울특별시    강북구      NaN        편 의 점
# 4      202011    1010          4010   서울특별시    강북구      NaN        편 의 점
# 5      202011    1014          4010   서울특별시    강북구      NaN        편 의 점
# 6      202011    1020          4010   서울특별시    강북구      NaN        편 의 점
# 7      202011    1023          4010   서울특별시    강북구      NaN        편 의 점
# 8      202011    1023          4020   서울특별시    강북구      NaN        슈퍼 마켓
# 9      202011    1024          4010   서울특별시    강북구      NaN        편 의 점
# 10     202011    1028          4020   서울특별시    강북구      NaN        슈퍼 마켓
# 11     202011    1029          4010   서울특별시    강북구      NaN        편 의 점
# 12     202011    1029          4020   서울특별시    강북구      NaN        슈퍼 마켓
# 13     202011    1030          4010   서울특별시    강북구      NaN        편 의 점
# 14     202011    1031          4010   서울특별시    강북구      NaN        편 의 점
# 15     202011    1035          4010   서울특별시    강북구      NaN        편 의 점
# 16     202011    1041          4010   서울특별시    강북구      NaN        편 의 점
# 17     202011    1041          4020   서울특별시    강북구      NaN        슈퍼 마켓
# 18     202011    1042          4010   서울특별시    강북구      NaN        편 의 점
# 19     202011    1043          4010   서울특별시    강북구      NaN        편 의 점
# 20     202011    1044          4010   서울특별시    강북구      NaN        편 의 점
# 21     202011    1044          8006   서울특별시    강북구      NaN         서양음식
# 22     202011    1045          4010   서울특별시    강북구      NaN        편 의 점
# 23     202011    1047          4010   서울특별시    강북구      NaN        편 의 점
# 24     202011    1047          4020   서울특별시    강북구      NaN        슈퍼 마켓
# 25     202011    1053          4020   서울특별시    강북구      NaN        슈퍼 마켓
# 26     202011    1054          4010   서울특별시    강북구      NaN        편 의 점
# 27     202011    1055          4010   서울특별시    강북구      NaN        편 의 점
# 28     202011    1056          2199   서울특별시    강북구      NaN        기타레져업
# 29     202011    1056          4010   서울특별시    강북구      NaN        편 의 점
# 30     202011    1056          4020   서울특별시    강북구      NaN        슈퍼 마켓
# 31     202011    1059          4010   서울특별시    강북구      NaN        편 의 점
# 32     202011    1062          4010   서울특별시    강북구      NaN        편 의 점
# 33     202011    1062          8001   서울특별시    강북구      NaN         일반한식
# 34     202011    1063          4020   서울특별시    강북구      NaN        슈퍼 마켓
# 35     202011    1063          8006   서울특별시    강북구      NaN         서양음식
# 36     202011    1064          4010   서울특별시    강북구      NaN        편 의 점
# 37     202011    1066          4020   서울특별시    강북구      NaN        슈퍼 마켓
# 38     202011    1071          4010   서울특별시    강북구      NaN        편 의 점
# 39     202011    1072          4010   서울특별시    강북구      NaN        편 의 점
# 40     202011    1072          8006   서울특별시    강북구      NaN         서양음식
# 41     202011    1076          4010   서울특별시    강북구      NaN        편 의 점
# 42     202011    1076          4020   서울특별시    강북구      NaN        슈퍼 마켓
# 43     202011    1078          4010   서울특별시    강북구      NaN        편 의 점
# 44     202011    1079          4010   서울특별시    강북구      NaN        편 의 점
# 45     202011    1079          4020   서울특별시    강북구      NaN        슈퍼 마켓
# 46     202011    1080          4010   서울특별시    강북구      NaN        편 의 점
# 47     202011    1080          4020   서울특별시    강북구      NaN        슈퍼 마켓
# 48     202011    1081          4010   서울특별시    강북구      NaN        편 의 점
# 49     202011    1090          4020   서울특별시    강북구      NaN        슈퍼 마켓
#
#     sale_amt
# 0      96844
# 1       8817
# 2      14564
# 3      33400
# 4       5100
# 5      58788
# 6       4100
# 7       6707
# 8      12373
# 9      18823
# 10     33243
# 11     32403
# 12      4100
# 13     26230
# 14     59581
# 15     12134
# 16      5167
# 17    284938
# 18     33766
# 19     13986
# 20     43952
# 21      7367
# 22     16966
# 23     14433
# 24    237144
# 25     17647
# 26     18273
# 27     59330
# 28     20100
# 29      7674
# 30     35416
# 31      4133
# 32     14433
# 33     25200
# 34     16573
# 35      5500
# 36      8423
# 37     29527
# 38      8733
# 39      3667
# 40      4700
# 41     61875
# 42    178919
# 43     12566
# 44      8563
# 45     21410
# 46    205291
# 47     23020
# 48     27293
# 49     43910
